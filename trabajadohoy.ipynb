# %% [markdown]
# # Proyecto 5

# %% [markdown]
# Para comenzar importamos las librerias a utilizar

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import functions as F

# %% [markdown]
# ## Carga datos clientes

# %%
df = pd.read_csv('df_final_demo.txt')

# %% [markdown]
# Observamos los datos

# %%
df.head()
# Out:
#    client_id  clnt_tenure_yr  clnt_tenure_mnth  clnt_age gendr  num_accts  \
# 0     836976             6.0              73.0      60.5     U        2.0
# 1    2304905             7.0              94.0      58.0     U        2.0
# 2    1439522             5.0              64.0      32.0     U        2.0
# 3    1562045            16.0             198.0      49.0     M        2.0
# 4    5126305            12.0             145.0      33.0     F        2.0
#
#          bal  calls_6_mnth  logons_6_mnth
# 0   45105.30           6.0            9.0
# 1  110860.30           6.0            9.0
# 2   52467.79           6.0            9.0
# 3   67454.65           3.0            6.0
# 4  103671.75           0.0            3.0

# %% [markdown]
# ### Analizamos los datos

# %%
F.explorar_df(df)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 70609 entries, 0 to 70608
# Data columns (total 9 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   client_id         70609 non-null  int64
#  1   clnt_tenure_yr    70595 non-null  float64
#  2   clnt_tenure_mnth  70595 non-null  float64
#  3   clnt_age          70594 non-null  float64
#  4   gendr             70595 non-null  object
#  5   num_accts         70595 non-null  float64
#  6   bal               70595 non-null  float64
#  7   calls_6_mnth      70595 non-null  float64
#  8   logons_6_mnth     70595 non-null  float64
# dtypes: float64(7), int64(1), object(1)
# memory usage: 4.8+ MB
# None
# Primeras filas
#    client_id  clnt_tenure_yr  clnt_tenure_mnth  clnt_age gendr  num_accts  \
# 0     836976             6.0              73.0      60.5     U        2.0
# 1    2304905             7.0              94.0      58.0     U        2.0
# 2    1439522             5.0              64.0      32.0     U        2.0
# 3    1562045            16.0             198.0      49.0     M        2.0
# 4    5126305            12.0             145.0      33.0     F        2.0
#
#          bal  calls_6_mnth  logons_6_mnth
# 0   45105.30           6.0            9.0
# 1  110860.30           6.0            9.0
# 2   52467.79           6.0            9.0
# 3   67454.65           3.0            6.0
# 4  103671.75           0.0            3.0
# Describe()
#                     count unique  top   freq            mean             std  \
# client_id         70609.0    NaN  NaN    NaN  5004991.876574  2877277.629755
# clnt_tenure_yr    70595.0    NaN  NaN    NaN        12.05295        6.871819
# clnt_tenure_mnth  70595.0    NaN  NaN    NaN      150.659367       82.089854
# clnt_age          70594.0    NaN  NaN    NaN        46.44224       15.591273
# gendr               70595      4    U  24122             NaN             NaN
# num_accts         70595.0    NaN  NaN    NaN        2.255528        0.534997
# bal               70595.0    NaN  NaN    NaN   147445.240641   301508.706531
# calls_6_mnth      70595.0    NaN  NaN    NaN        3.382478         2.23658
# logons_6_mnth     70595.0    NaN  NaN    NaN         5.56674        2.353286
#
#                        min        25%        50%         75%          max
# client_id            169.0  2519329.0  5016978.0   7483085.0    9999839.0
# clnt_tenure_yr         2.0        6.0       11.0        16.0         62.0
# clnt_tenure_mnth      33.0       82.0      136.0       192.0        749.0
# clnt_age              13.5       32.5       47.0        59.0         96.0
# gendr                  NaN        NaN        NaN         NaN          NaN
# num_accts              1.0        2.0        2.0         2.0          8.0
# bal               13789.42  37346.835    63332.9  137544.905  16320040.15
# calls_6_mnth           0.0        1.0        3.0         6.0          7.0
# logons_6_mnth          1.0        4.0        5.0         7.0          9.0
# Nulos
# clnt_tenure_yr      14
# clnt_tenure_mnth    14
# clnt_age            15
# gendr               14
# num_accts           14
# bal                 14
# calls_6_mnth        14
# logons_6_mnth       14
# dtype: int64
# Duplicados
# 0
# Tamaño
# Filas: 70609 | Columnas: 9

# %% [markdown]
# Analizamos los nulos

# %%
nulos=F.ver_nulos(df)
# Out:
#        client_id  clnt_tenure_yr  clnt_tenure_mnth  clnt_age gendr  num_accts  \
# 4164     7402828             NaN               NaN       NaN   NaN        NaN
# 8316      355337             NaN               NaN       NaN   NaN        NaN
# 8677     8412164             NaN               NaN       NaN   NaN        NaN
# 9583     4666211             8.0             106.0       NaN     F        2.0
# 13444    2222915             NaN               NaN       NaN   NaN        NaN
# 18066    4876926             NaN               NaN       NaN   NaN        NaN
# 25961    5277910             NaN               NaN       NaN   NaN        NaN
# 28432    7616759             NaN               NaN       NaN   NaN        NaN
# 35323    8191345             NaN               NaN       NaN   NaN        NaN
# 43518    1227228             NaN               NaN       NaN   NaN        NaN
# 46076    8611797             NaN               NaN       NaN   NaN        NaN
# 47189    5144725             NaN               NaN       NaN   NaN        NaN
# 49846    1037867             NaN               NaN       NaN   NaN        NaN
# 63701    1618749             NaN               NaN       NaN   NaN        NaN
# 66219    6021001             NaN               NaN       NaN   NaN        NaN
#
#             bal  calls_6_mnth  logons_6_mnth
# 4164        NaN           NaN            NaN
# 8316        NaN           NaN            NaN
# 8677        NaN           NaN            NaN
# 9583   42550.55           4.0            7.0
# 13444       NaN           NaN            NaN
# 18066       NaN           NaN            NaN
# 25961       NaN           NaN            NaN
# 28432       NaN           NaN            NaN
# 35323       NaN           NaN            NaN
# 43518       NaN           NaN            NaN
# 46076       NaN           NaN            NaN
# 47189       NaN           NaN            NaN
# 49846       NaN           NaN            NaN
# 63701       NaN           NaN            NaN
# 66219       NaN           NaN            NaN

# %% [markdown]
# ### Limpieza de datos

# %% [markdown]
# Eliminaremos las columnas que no aportan información relevante para el análisis, ya que solo tienen valores nulos y el nombre del cliente

# %%
#Eliminamos nulos sin información solo el cliente

df3=df.dropna(subset=['clnt_tenure_yr','clnt_tenure_mnth','gendr','num_accts','bal','calls_6_mnth','logons_6_mnth'])

# %%
df3
# Out:
#        client_id  clnt_tenure_yr  clnt_tenure_mnth  clnt_age gendr  num_accts  \
# 0         836976             6.0              73.0      60.5     U        2.0
# 1        2304905             7.0              94.0      58.0     U        2.0
# 2        1439522             5.0              64.0      32.0     U        2.0
# 3        1562045            16.0             198.0      49.0     M        2.0
# 4        5126305            12.0             145.0      33.0     F        2.0
# ...          ...             ...               ...       ...   ...        ...
# 70604    7993686             4.0              56.0      38.5     U        3.0
# 70605    8981690            12.0             148.0      31.0     M        2.0
# 70606     333913            16.0             198.0      61.5     F        2.0
# 70607    1573142            21.0             255.0      68.0     M        3.0
# 70608    5602139            21.0             254.0      59.5     F        3.0
#
#               bal  calls_6_mnth  logons_6_mnth
# 0        45105.30           6.0            9.0
# 1       110860.30           6.0            9.0
# 2        52467.79           6.0            9.0
# 3        67454.65           3.0            6.0
# 4       103671.75           0.0            3.0
# ...           ...           ...            ...
# 70604  1411062.68           5.0            5.0
# 70605   101867.07           6.0            6.0
# 70606    40745.00           3.0            3.0
# 70607   475114.69           4.0            4.0
# 70608   157498.73           7.0            7.0
#
# [70595 rows x 9 columns]

# %% [markdown]
# Reemplazamos el nulo de la edad con la media ??? o lo anulamos??

# %%
F.ver_nulos(df3)
# Out:
#       client_id  clnt_tenure_yr  clnt_tenure_mnth  clnt_age gendr  num_accts  \
# 9583    4666211             8.0             106.0       NaN     F        2.0
#
#            bal  calls_6_mnth  logons_6_mnth
# 9583  42550.55           4.0            7.0

# %%
valor=df3['clnt_age'].mean()
df4=F.completar_nulos(df3,'clnt_age',valor)
# Out:
# c:\Users\tachi\Documents\git\ensayo\Proyecto largo\functions.py:55: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[col] = df[col].fillna(valor)

# %%
F.ver_nulos(df4)
# Out:
# Empty DataFrame
# Columns: [client_id, clnt_tenure_yr, clnt_tenure_mnth, clnt_age, gendr, num_accts, bal, calls_6_mnth, logons_6_mnth]
# Index: []

# %% [markdown]
# Haremos la limpieza de datos final

# %%
df_clean = F.limpiar_dataset(df4)
df_clean
# Out:
#        client_id  clnt_tenure_yr  clnt_tenure_mnth  clnt_age gendr  num_accts  \
# 0         836976             6.0              73.0      60.5     U        2.0
# 1        2304905             7.0              94.0      58.0     U        2.0
# 2        1439522             5.0              64.0      32.0     U        2.0
# 3        1562045            16.0             198.0      49.0     M        2.0
# 4        5126305            12.0             145.0      33.0     F        2.0
# ...          ...             ...               ...       ...   ...        ...
# 70604    7993686             4.0              56.0      38.5     U        3.0
# 70605    8981690            12.0             148.0      31.0     M        2.0
# 70606     333913            16.0             198.0      61.5     F        2.0
# 70607    1573142            21.0             255.0      68.0     M        3.0
# 70608    5602139            21.0             254.0      59.5     F        3.0
#
#               bal  calls_6_mnth  logons_6_mnth
# 0        45105.30           6.0            9.0
# 1       110860.30           6.0            9.0
# 2        52467.79           6.0            9.0
# 3        67454.65           3.0            6.0
# 4       103671.75           0.0            3.0
# ...           ...           ...            ...
# 70604  1411062.68           5.0            5.0
# 70605   101867.07           6.0            6.0
# 70606    40745.00           3.0            3.0
# 70607   475114.69           4.0            4.0
# 70608   157498.73           7.0            7.0
#
# [70595 rows x 9 columns]

# %% [markdown]
# ## Responda las siguientes preguntas sobre demografía:
#
# ¿Quiénes son los principales clientes que utilizan este proceso en línea?
# ¿Los clientes principales son más jóvenes o mayores, nuevos o antiguos?
# A continuación, realice un análisis del comportamiento del cliente para responder cualquier pregunta adicional relevante que considere importante

# %% [markdown]
# Veamos como se comporta la variable edad

# %%
F.categorico(df_clean, 'clnt_age')
# Out:
# clnt_age
# 58.50000    859
# 55.50000    830
# 29.50000    829
# 28.50000    827
# 57.50000    826
#            ...
# 14.00000      2
# 95.50000      1
# 94.50000      1
# 46.44224      1
# 13.50000      1
# Name: count, Length: 166, dtype: int64
# [60.5        58.         32.         49.         33.         30.5
#  58.5        57.5        67.5        54.5        34.5        51.5
#  62.5        36.         74.         32.5        31.         25.5
#  42.5        42.         30.         55.         38.         68.5
#  52.5        54.         63.         48.         66.5        68.
#  65.         51.         46.         63.5        23.         26.5
#  56.5        76.5        27.5        39.5        25.         27.
#  60.         66.         39.         56.         40.         52.
#  31.5        43.5        35.         19.         64.5        64.
#  22.5        33.5        36.5        61.         40.5        72.
#  44.5        28.5        59.5        45.         18.         78.
#  50.5        29.         37.5        57.         70.         74.5
#  22.         50.         53.         62.         65.5        29.5
#  28.         69.5        35.5        71.5        34.         38.5
#  69.         43.         83.5        21.5        47.         61.5
#  73.5        71.         59.         21.         44.         83.
#  47.5        72.5        76.         78.5        55.5        67.
#  41.5        20.5        75.         24.         79.         26.
#  41.         23.5        49.5        46.5        45.5        48.5
#  24.5        75.5        80.         73.         87.         19.5
#  53.5        18.5        70.5        80.5        86.         37.
#  85.         17.5        82.         20.         77.5        77.
#  79.5        88.5        96.         81.         81.5        88.
#  84.         94.5        89.         92.         82.5        91.5
#  85.5        95.5        84.5        90.         89.5        93.
#  46.44224013 90.5        87.5        93.5        86.5        91.
#  17.         94.         92.5        15.5        16.         16.5
#  14.5        15.         14.         13.5       ]
# 166

# %% [markdown]
# Construimos la tabla de frecuencias por grupos de edades agregando una nueva columna con los rangos de edad

# %%
def rango_edad(df,col):
    """Crea rangos de edad a partir de una columna numérica."""
    df4=df.copy()
    bins = [0, 18, 35, 50, 65, 120]
    labels = ['Niños(0-18)', 'Jóvenes(19-35)', 'Adultos(36-50)', 'Adultos maduros(51-65)', 'Adultos mayores(66+)']
    
    df4['age_group'] = pd.cut(df[col], bins=bins, labels=labels)
    
    return df4

# %%
F.categorico(df_clean,"client_id")
# Out:
# client_id
# 836976     1
# 2304905    1
# 1439522    1
# 1562045    1
# 5126305    1
#           ..
# 7993686    1
# 8981690    1
# 333913     1
# 1573142    1
# 5602139    1
# Name: count, Length: 70595, dtype: int64
# [ 836976 2304905 1439522 ...  333913 1573142 5602139]
# 70595

# %%
df_clean1=rango_edad(df_clean,'clnt_age')

# %%
df_clean1
# Out:
#        client_id  clnt_tenure_yr  clnt_tenure_mnth  clnt_age gendr  num_accts  \
# 0         836976             6.0              73.0      60.5     U        2.0
# 1        2304905             7.0              94.0      58.0     U        2.0
# 2        1439522             5.0              64.0      32.0     U        2.0
# 3        1562045            16.0             198.0      49.0     M        2.0
# 4        5126305            12.0             145.0      33.0     F        2.0
# ...          ...             ...               ...       ...   ...        ...
# 70604    7993686             4.0              56.0      38.5     U        3.0
# 70605    8981690            12.0             148.0      31.0     M        2.0
# 70606     333913            16.0             198.0      61.5     F        2.0
# 70607    1573142            21.0             255.0      68.0     M        3.0
# 70608    5602139            21.0             254.0      59.5     F        3.0
#
#               bal  calls_6_mnth  logons_6_mnth               age_group
# 0        45105.30           6.0            9.0  Adultos maduros(51-65)
# 1       110860.30           6.0            9.0  Adultos maduros(51-65)
# 2        52467.79           6.0            9.0          Jóvenes(19-35)
# 3        67454.65           3.0            6.0          Adultos(36-50)
# 4       103671.75           0.0            3.0          Jóvenes(19-35)
# ...           ...           ...            ...                     ...
# 70604  1411062.68           5.0            5.0          Adultos(36-50)
# 70605   101867.07           6.0            6.0          Jóvenes(19-35)
# 70606    40745.00           3.0            3.0  Adultos maduros(51-65)
# 70607   475114.69           4.0            4.0    Adultos mayores(66+)
# 70608   157498.73           7.0            7.0  Adultos maduros(51-65)
#
# [70595 rows x 10 columns]

# %% [markdown]
# ### Visualización del dataset

# %%
counts = df_clean1['age_group'].value_counts()

plt.bar(counts.index, counts.values, color=sns.color_palette('pastel'))

plt.xlabel('Grupo de Edad')
plt.ylabel('Cantidad')
plt.xticks(rotation=45)

plt.show()

# %%
df_clean.hist()
# Out:
# array([[<Axes: title={'center': 'client_id'}>,
#         <Axes: title={'center': 'clnt_tenure_yr'}>,
#         <Axes: title={'center': 'clnt_tenure_mnth'}>],
#        [<Axes: title={'center': 'clnt_age'}>,
#         <Axes: title={'center': 'num_accts'}>,
#         <Axes: title={'center': 'bal'}>],
#        [<Axes: title={'center': 'calls_6_mnth'}>,
#         <Axes: title={'center': 'logons_6_mnth'}>, <Axes: >]],
#       dtype=object)

# %% [markdown]
# ## Carga datos Huellas digitales

# %%
df_huellas1 = pd.read_csv('df_final_web_data_pt_1.txt')

# %% [markdown]
# Observamos la estructura del dataset

# %%
df_huellas1.head()
# Out:
#    client_id            visitor_id                      visit_id process_step  \
# 0    9988021  580560515_7732621733  781255054_21935453173_531117       step_3
# 1    9988021  580560515_7732621733  781255054_21935453173_531117       step_2
# 2    9988021  580560515_7732621733  781255054_21935453173_531117       step_3
# 3    9988021  580560515_7732621733  781255054_21935453173_531117       step_2
# 4    9988021  580560515_7732621733  781255054_21935453173_531117       step_3
#
#              date_time
# 0  2017-04-17 15:27:07
# 1  2017-04-17 15:26:51
# 2  2017-04-17 15:19:22
# 3  2017-04-17 15:19:13
# 4  2017-04-17 15:18:04

# %% [markdown]
# Analizamos los datos

# %%
F.explorar_df(df_huellas1)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 343141 entries, 0 to 343140
# Data columns (total 5 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   client_id     343141 non-null  int64
#  1   visitor_id    343141 non-null  object
#  2   visit_id      343141 non-null  object
#  3   process_step  343141 non-null  object
#  4   date_time     343141 non-null  object
# dtypes: int64(1), object(4)
# memory usage: 13.1+ MB
# None
# Primeras filas
#    client_id            visitor_id                      visit_id process_step  \
# 0    9988021  580560515_7732621733  781255054_21935453173_531117       step_3
# 1    9988021  580560515_7732621733  781255054_21935453173_531117       step_2
# 2    9988021  580560515_7732621733  781255054_21935453173_531117       step_3
# 3    9988021  580560515_7732621733  781255054_21935453173_531117       step_2
# 4    9988021  580560515_7732621733  781255054_21935453173_531117       step_3
#
#              date_time
# 0  2017-04-17 15:27:07
# 1  2017-04-17 15:26:51
# 2  2017-04-17 15:19:22
# 3  2017-04-17 15:19:13
# 4  2017-04-17 15:18:04
# Describe()
#                  count  unique                          top    freq  \
# client_id     343141.0     NaN                          NaN     NaN
# visitor_id      343141   62936        699275239_82397698587      66
# visit_id        343141   75256  712824876_8175482950_365042      61
# process_step    343141       5                        start  108910
# date_time       343141  282666          2017-03-29 11:24:54      14
#
#                         mean             std    min        25%        50%  \
# client_id     4996097.072227  2875838.608021  169.0  2506067.0  5007915.0
# visitor_id               NaN             NaN    NaN        NaN        NaN
# visit_id                 NaN             NaN    NaN        NaN        NaN
# process_step             NaN             NaN    NaN        NaN        NaN
# date_time                NaN             NaN    NaN        NaN        NaN
#
#                     75%        max
# client_id     7468519.0  9999839.0
# visitor_id          NaN        NaN
# visit_id            NaN        NaN
# process_step        NaN        NaN
# date_time           NaN        NaN
# Nulos
# Notnnull
# Duplicados
# 2095
# Tamaño
# Filas: 343141 | Columnas: 5

# %% [markdown]
# No tenemos nulos pero si duplicados. Veamos los duplicados:

# %%
duplicados=F.ver_duplicados(df_huellas1)
# Out:
#         client_id             visitor_id                      visit_id  \
# 365       9358626  148475529_63668223960  223297395_36250329195_832161
# 368       5376894  622509328_44408201172  688984457_43441834354_912755
# 383        438567  923318467_50708963627  330543236_29863358529_771432
# 785       1423857  716830992_81930238382   568819166_80596727019_75889
# 1816       372523  730241475_25771921122   25331354_74479847014_854987
# ...           ...                    ...                           ...
# 342621    1853345  831456815_77348510380  596026060_87178689141_910423
# 342677    1251269  791822615_78146852845   763845944_55757914723_70888
# 342679    1251269  791822615_78146852845   763845944_55757914723_70888
# 342685    8350388  304440669_31040182888  143359398_96671536668_299057
# 342945    4553664  795008403_33653570753  439592710_65772985411_546352
#
#        process_step            date_time
# 365           start  2017-04-28 12:27:28
# 368           start  2017-04-28 14:20:01
# 383           start  2017-04-28 02:52:29
# 785         confirm  2017-04-10 22:44:58
# 1816          start  2017-04-27 10:51:26
# ...             ...                  ...
# 342621       step_3  2017-04-13 19:39:24
# 342677        start  2017-04-28 10:20:33
# 342679        start  2017-04-28 10:18:20
# 342685        start  2017-04-28 12:44:21
# 342945        start  2017-04-28 07:07:17
#
# [2095 rows x 5 columns]

# %% [markdown]
# Gestionar y analizar los duplicados

# %% [markdown]
# ### Cargamos los datos del segundo archivo de huellas

# %%
df_huellas2 = pd.read_csv('df_final_web_data_pt_2.txt')

# %% [markdown]
# Observamos el segundo archivo de huellas:

# %%
df_huellas2.head()
# Out:
#    client_id             visitor_id                      visit_id  \
# 0     763412  601952081_10457207388  397475557_40440946728_419634
# 1    6019349  442094451_91531546617  154620534_35331068705_522317
# 2    6019349  442094451_91531546617  154620534_35331068705_522317
# 3    6019349  442094451_91531546617  154620534_35331068705_522317
# 4    6019349  442094451_91531546617  154620534_35331068705_522317
#
#   process_step            date_time
# 0      confirm  2017-06-06 08:56:00
# 1      confirm  2017-06-01 11:59:27
# 2       step_3  2017-06-01 11:58:48
# 3       step_2  2017-06-01 11:58:08
# 4       step_1  2017-06-01 11:57:58

# %% [markdown]
# Analizamos los datos

# %%
F.explorar_df(df_huellas2)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 412264 entries, 0 to 412263
# Data columns (total 5 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   client_id     412264 non-null  int64
#  1   visitor_id    412264 non-null  object
#  2   visit_id      412264 non-null  object
#  3   process_step  412264 non-null  object
#  4   date_time     412264 non-null  object
# dtypes: int64(1), object(4)
# memory usage: 15.7+ MB
# None
# Primeras filas
#    client_id             visitor_id                      visit_id  \
# 0     763412  601952081_10457207388  397475557_40440946728_419634
# 1    6019349  442094451_91531546617  154620534_35331068705_522317
# 2    6019349  442094451_91531546617  154620534_35331068705_522317
# 3    6019349  442094451_91531546617  154620534_35331068705_522317
# 4    6019349  442094451_91531546617  154620534_35331068705_522317
#
#   process_step            date_time
# 0      confirm  2017-06-06 08:56:00
# 1      confirm  2017-06-01 11:59:27
# 2       step_3  2017-06-01 11:58:48
# 3       step_2  2017-06-01 11:58:08
# 4       step_1  2017-06-01 11:57:58
# Describe()
#                  count  unique                           top    freq  \
# client_id     412264.0     NaN                           NaN     NaN
# visitor_id      412264   71042          722943003_3441581446     104
# visit_id        412264   82841  875138661_34710212496_881092     104
# process_step    412264       5                         start  135035
# date_time       412264  346697           2017-05-02 10:53:01      24
#
#                        mean            std    min        25%        50%  \
# client_id     5028227.11113  2881828.33504  336.0  2533952.0  5056314.0
# visitor_id              NaN            NaN    NaN        NaN        NaN
# visit_id                NaN            NaN    NaN        NaN        NaN
# process_step            NaN            NaN    NaN        NaN        NaN
# date_time               NaN            NaN    NaN        NaN        NaN
#
#                      75%        max
# client_id     7516791.75  9999875.0
# visitor_id           NaN        NaN
# visit_id             NaN        NaN
# process_step         NaN        NaN
# date_time            NaN        NaN
# Nulos
# Notnnull
# Duplicados
# 8669
# Tamaño
# Filas: 412264 | Columnas: 5

# %% [markdown]
# Igual que antes, no tenemos nulos pero si duplicados. Veamos los duplicados:

# %%
duplicados2=F.ver_duplicados(df_huellas2)
# Out:
#         client_id             visitor_id                      visit_id  \
# 125       3751049  937925261_74821699083  628817270_45049432060_475841
# 143       9912156  746623513_52101087617  780044921_57678038107_984942
# 326       5786602  893139880_61416949586  747153834_69434320996_858907
# 328       5786602  893139880_61416949586  747153834_69434320996_858907
# 375       5786602  893139880_61416949586   119968876_5423296886_390511
# ...           ...                    ...                           ...
# 412120    1672289  658797407_91003097342  430110748_90347503221_597628
# 412163    4408245   14058946_73585431797  994148957_84373994761_991865
# 412165    4408245   14058946_73585431797  994148957_84373994761_991865
# 412167    4408245   14058946_73585431797  994148957_84373994761_991865
# 412217    3897324   80177429_24869309091  149796456_64325617570_112561
#
#        process_step            date_time
# 125           start  2017-05-15 23:09:44
# 143           start  2017-05-03 14:09:52
# 326           start  2017-05-10 01:49:09
# 328           start  2017-05-10 01:48:45
# 375           start  2017-06-08 02:14:09
# ...             ...                  ...
# 412120        start  2017-05-01 19:28:53
# 412163        start  2017-06-06 09:17:23
# 412165        start  2017-06-06 09:09:44
# 412167        start  2017-06-06 08:51:16
# 412217        start  2017-05-04 08:21:30
#
# [8669 rows x 5 columns]

# %% [markdown]
# Gestionar y analizar los duplicados Unir los datos de las huellas

# %% [markdown]
# # FALTANTES:

# %% [markdown]
# ### uniendo los datasets

# %%
df_union = pd.concat([df_huellas1, df_huellas2], axis=0, ignore_index=True)

# %%
df_union.head()
# Out:
#    client_id            visitor_id                      visit_id process_step  \
# 0    9988021  580560515_7732621733  781255054_21935453173_531117       step_3
# 1    9988021  580560515_7732621733  781255054_21935453173_531117       step_2
# 2    9988021  580560515_7732621733  781255054_21935453173_531117       step_3
# 3    9988021  580560515_7732621733  781255054_21935453173_531117       step_2
# 4    9988021  580560515_7732621733  781255054_21935453173_531117       step_3
#
#              date_time
# 0  2017-04-17 15:27:07
# 1  2017-04-17 15:26:51
# 2  2017-04-17 15:19:22
# 3  2017-04-17 15:19:13
# 4  2017-04-17 15:18:04

# %%
F.explorar_df(df_union)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 755405 entries, 0 to 755404
# Data columns (total 5 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   client_id     755405 non-null  int64
#  1   visitor_id    755405 non-null  object
#  2   visit_id      755405 non-null  object
#  3   process_step  755405 non-null  object
#  4   date_time     755405 non-null  object
# dtypes: int64(1), object(4)
# memory usage: 28.8+ MB
# None
# Primeras filas
#    client_id            visitor_id                      visit_id process_step  \
# 0    9988021  580560515_7732621733  781255054_21935453173_531117       step_3
# 1    9988021  580560515_7732621733  781255054_21935453173_531117       step_2
# 2    9988021  580560515_7732621733  781255054_21935453173_531117       step_3
# 3    9988021  580560515_7732621733  781255054_21935453173_531117       step_2
# 4    9988021  580560515_7732621733  781255054_21935453173_531117       step_3
#
#              date_time
# 0  2017-04-17 15:27:07
# 1  2017-04-17 15:26:51
# 2  2017-04-17 15:19:22
# 3  2017-04-17 15:19:13
# 4  2017-04-17 15:18:04
# Describe()
#                  count  unique                           top    freq  \
# client_id     755405.0     NaN                           NaN     NaN
# visitor_id      755405  130236          722943003_3441581446     104
# visit_id        755405  158095  875138661_34710212496_881092     104
# process_step    755405       5                         start  243945
# date_time       755405  629363           2017-05-02 10:07:41      24
#
#                         mean             std    min        25%        50%  \
# client_id     5013632.114169  2879151.599558  169.0  2519882.0  5033441.0
# visitor_id               NaN             NaN    NaN        NaN        NaN
# visit_id                 NaN             NaN    NaN        NaN        NaN
# process_step             NaN             NaN    NaN        NaN        NaN
# date_time                NaN             NaN    NaN        NaN        NaN
#
#                     75%        max
# client_id     7496063.0  9999875.0
# visitor_id          NaN        NaN
# visit_id            NaN        NaN
# process_step        NaN        NaN
# date_time           NaN        NaN
# Nulos
# Notnnull
# Duplicados
# 10764
# Tamaño
# Filas: 755405 | Columnas: 5

# %%
duplicados = F.ver_duplicados(df_union)
# Out:
#         client_id             visitor_id                      visit_id  \
# 365       9358626  148475529_63668223960  223297395_36250329195_832161
# 368       5376894  622509328_44408201172  688984457_43441834354_912755
# 383        438567  923318467_50708963627  330543236_29863358529_771432
# 785       1423857  716830992_81930238382   568819166_80596727019_75889
# 1816       372523  730241475_25771921122   25331354_74479847014_854987
# ...           ...                    ...                           ...
# 755261    1672289  658797407_91003097342  430110748_90347503221_597628
# 755304    4408245   14058946_73585431797  994148957_84373994761_991865
# 755306    4408245   14058946_73585431797  994148957_84373994761_991865
# 755308    4408245   14058946_73585431797  994148957_84373994761_991865
# 755358    3897324   80177429_24869309091  149796456_64325617570_112561
#
#        process_step            date_time
# 365           start  2017-04-28 12:27:28
# 368           start  2017-04-28 14:20:01
# 383           start  2017-04-28 02:52:29
# 785         confirm  2017-04-10 22:44:58
# 1816          start  2017-04-27 10:51:26
# ...             ...                  ...
# 755261        start  2017-05-01 19:28:53
# 755304        start  2017-06-06 09:17:23
# 755306        start  2017-06-06 09:09:44
# 755308        start  2017-06-06 08:51:16
# 755358        start  2017-05-04 08:21:30
#
# [10764 rows x 5 columns]

# %%
def separa_fecha_hora (df,col):
    df[col] = pd.to_datetime(df[col].str.extract(r'(\d{4}-\d{2}-\d{2} \d{2}:\d{2}:\d{2})')[0])
    df['fecha'] = df[col].dt.date
    df['hora'] = df[col].dt.time
    df= df.drop(columns=[col])
    return df

# %%
separa_fecha_hora(df_union, 'date_time')
# Out:
#         client_id             visitor_id                      visit_id  \
# 0         9988021   580560515_7732621733  781255054_21935453173_531117
# 1         9988021   580560515_7732621733  781255054_21935453173_531117
# 2         9988021   580560515_7732621733  781255054_21935453173_531117
# 3         9988021   580560515_7732621733  781255054_21935453173_531117
# 4         9988021   580560515_7732621733  781255054_21935453173_531117
# ...           ...                    ...                           ...
# 755400    9668240   388766751_9038881013   922267647_3096648104_968866
# 755401    9668240   388766751_9038881013   922267647_3096648104_968866
# 755402    9668240   388766751_9038881013   922267647_3096648104_968866
# 755403    9668240   388766751_9038881013   922267647_3096648104_968866
# 755404     674799  947159805_81558194550   86152093_47511127657_716022
#
#        process_step       fecha      hora
# 0            step_3  2017-04-17  15:27:07
# 1            step_2  2017-04-17  15:26:51
# 2            step_3  2017-04-17  15:19:22
# 3            step_2  2017-04-17  15:19:13
# 4            step_3  2017-04-17  15:18:04
# ...             ...         ...       ...
# 755400        start  2017-05-24  18:46:10
# 755401        start  2017-05-24  18:45:29
# 755402       step_1  2017-05-24  18:44:51
# 755403        start  2017-05-24  18:44:34
# 755404        start  2017-06-03  12:17:09
#
# [755405 rows x 6 columns]

# %% [markdown]
# Agrupar por hora

# %%
def agrupar_hora(df,col):
    """Crea grupos a partir de las horas."""
    bins = [0, 6, 12, 18, 24]
    labels = ['Noche(0-6)', 'Mañana(6-12)', 'Tarde(12-18)', 'Noche(18-24)']
    
    horas_extraidas = pd.to_datetime(df[col], format='%H:%M:%S', errors='coerce').dt.hour
    
    df['hora_group'] = pd.cut(horas_extraidas, bins=bins, labels=labels, include_lowest=True)
    
    return df

# %%
agrupar_hora(df_union, 'hora')
# Out:
#         client_id             visitor_id                      visit_id  \
# 0         9988021   580560515_7732621733  781255054_21935453173_531117
# 1         9988021   580560515_7732621733  781255054_21935453173_531117
# 2         9988021   580560515_7732621733  781255054_21935453173_531117
# 3         9988021   580560515_7732621733  781255054_21935453173_531117
# 4         9988021   580560515_7732621733  781255054_21935453173_531117
# ...           ...                    ...                           ...
# 755400    9668240   388766751_9038881013   922267647_3096648104_968866
# 755401    9668240   388766751_9038881013   922267647_3096648104_968866
# 755402    9668240   388766751_9038881013   922267647_3096648104_968866
# 755403    9668240   388766751_9038881013   922267647_3096648104_968866
# 755404     674799  947159805_81558194550   86152093_47511127657_716022
#
#        process_step           date_time       fecha      hora    hora_group
# 0            step_3 2017-04-17 15:27:07  2017-04-17  15:27:07  Tarde(12-18)
# 1            step_2 2017-04-17 15:26:51  2017-04-17  15:26:51  Tarde(12-18)
# 2            step_3 2017-04-17 15:19:22  2017-04-17  15:19:22  Tarde(12-18)
# 3            step_2 2017-04-17 15:19:13  2017-04-17  15:19:13  Tarde(12-18)
# 4            step_3 2017-04-17 15:18:04  2017-04-17  15:18:04  Tarde(12-18)
# ...             ...                 ...         ...       ...           ...
# 755400        start 2017-05-24 18:46:10  2017-05-24  18:46:10  Tarde(12-18)
# 755401        start 2017-05-24 18:45:29  2017-05-24  18:45:29  Tarde(12-18)
# 755402       step_1 2017-05-24 18:44:51  2017-05-24  18:44:51  Tarde(12-18)
# 755403        start 2017-05-24 18:44:34  2017-05-24  18:44:34  Tarde(12-18)
# 755404        start 2017-06-03 12:17:09  2017-06-03  12:17:09  Mañana(6-12)
#
# [755405 rows x 8 columns]

# %%
grupo = df_union.groupby(['client_id', 'process_step']).size().reset_index(name='conteo')

# %%
grupo
# Out:
#         client_id process_step  conteo
# 0             169      confirm       1
# 1             169        start       1
# 2             169       step_1       1
# 3             169       step_2       1
# 4             169       step_3       1
# ...           ...          ...     ...
# 493117    9999875      confirm       1
# 493118    9999875        start       1
# 493119    9999875       step_1       2
# 493120    9999875       step_2       1
# 493121    9999875       step_3       1
#
# [493122 rows x 3 columns]

# %%
grupo.sort_values('conteo', ascending=False).query('conteo > 5')
# Out:
#         client_id process_step  conteo
# 103996    2128341        start      67
# 374386    7597144        start      54
# 44889      913770        start      49
# 275214    5601303        start      47
# 485712    9852814        start      44
# ...           ...          ...     ...
# 212312    4326909        start       6
# 313857    6379561        start       6
# 344652    7002612        start       6
# 14403      292258        start       6
# 14429      292662        start       6
#
# [8400 rows x 3 columns]

# %%
F.categorico(df_union,"hora_group")
# Out:
# hora_group
# Mañana(6-12)    288812
# Tarde(12-18)    284257
# Noche(18-24)    146730
# Noche(0-6)       35606
# Name: count, dtype: int64
# ['Tarde(12-18)', 'Mañana(6-12)', 'Noche(18-24)', 'Noche(0-6)']
# Categories (4, object): ['Noche(0-6)' < 'Mañana(6-12)' < 'Tarde(12-18)' < 'Noche(18-24)']
# 4

# %% [markdown]
# La mayoría de los clientes tienen sus atenciones en la mañana y tarde.

# %%
F.categorico(df_union,"client_id")
# Out:
# client_id
# 5574879    111
# 2274658     90
# 2128341     84
# 5951379     81
# 1595223     81
#           ...
# 1200258      1
# 4532140      1
# 1418419      1
# 1740430      1
# 1279022      1
# Name: count, Length: 120157, dtype: int64
# [9988021 8320017 4033851 ... 9895983 9668240  674799]
# 120157

# %%
F.categorico(df_union,"process_step")
# Out:
# process_step
# start      243945
# step_1     163193
# step_2     133062
# step_3     112242
# confirm    102963
# Name: count, dtype: int64
# ['step_3' 'step_2' 'step_1' 'start' 'confirm']
# 5

# %%
F.categorico(df_union,"fecha")
# Out:
# fecha
# 2017-03-29    45798
# 2017-06-01    39140
# 2017-04-05    35473
# 2017-05-24    32979
# 2017-04-12    25507
#               ...
# 2017-04-29      460
# 2017-03-17      434
# 2017-03-18      428
# 2017-03-25      416
# 2017-03-21      405
# Name: count, Length: 98, dtype: int64
# [datetime.date(2017, 4, 17) datetime.date(2017, 4, 5)
#  datetime.date(2017, 4, 16) datetime.date(2017, 4, 4)
#  datetime.date(2017, 4, 10) datetime.date(2017, 4, 3)
#  datetime.date(2017, 4, 2) datetime.date(2017, 3, 29)
#  datetime.date(2017, 4, 12) datetime.date(2017, 3, 26)
#  datetime.date(2017, 4, 13) datetime.date(2017, 4, 6)
#  datetime.date(2017, 3, 27) datetime.date(2017, 3, 22)
#  datetime.date(2017, 4, 9) datetime.date(2017, 4, 18)
#  datetime.date(2017, 4, 11) datetime.date(2017, 4, 19)
#  datetime.date(2017, 3, 15) datetime.date(2017, 3, 28)
#  datetime.date(2017, 4, 20) datetime.date(2017, 4, 24)
#  datetime.date(2017, 4, 25) datetime.date(2017, 3, 30)
#  datetime.date(2017, 4, 27) datetime.date(2017, 4, 7)
#  datetime.date(2017, 4, 14) datetime.date(2017, 3, 31)
#  datetime.date(2017, 4, 8) datetime.date(2017, 4, 1)
#  datetime.date(2017, 3, 24) datetime.date(2017, 4, 23)
#  datetime.date(2017, 4, 28) datetime.date(2017, 4, 22)
#  datetime.date(2017, 3, 19) datetime.date(2017, 4, 21)
#  datetime.date(2017, 4, 15) datetime.date(2017, 3, 20)
#  datetime.date(2017, 3, 21) datetime.date(2017, 3, 25)
#  datetime.date(2017, 4, 26) datetime.date(2017, 4, 30)
#  datetime.date(2017, 4, 29) datetime.date(2017, 3, 17)
#  datetime.date(2017, 3, 23) datetime.date(2017, 3, 18)
#  datetime.date(2017, 3, 16) datetime.date(2017, 6, 6)
#  datetime.date(2017, 6, 1) datetime.date(2017, 6, 5)
#  datetime.date(2017, 5, 10) datetime.date(2017, 6, 12)
#  datetime.date(2017, 6, 7) datetime.date(2017, 6, 4)
#  datetime.date(2017, 5, 22) datetime.date(2017, 6, 11)
#  datetime.date(2017, 6, 14) datetime.date(2017, 5, 11)
#  datetime.date(2017, 6, 8) datetime.date(2017, 5, 31)
#  datetime.date(2017, 5, 16) datetime.date(2017, 5, 15)
#  datetime.date(2017, 5, 30) datetime.date(2017, 5, 23)
#  datetime.date(2017, 6, 15) datetime.date(2017, 5, 3)
#  datetime.date(2017, 5, 24) datetime.date(2017, 6, 2)
#  datetime.date(2017, 6, 9) datetime.date(2017, 6, 16)
#  datetime.date(2017, 5, 19) datetime.date(2017, 6, 3)
#  datetime.date(2017, 5, 12) datetime.date(2017, 5, 13)
#  datetime.date(2017, 6, 10) datetime.date(2017, 5, 28)
#  datetime.date(2017, 5, 27) datetime.date(2017, 5, 20)
#  datetime.date(2017, 6, 13) datetime.date(2017, 5, 9)
#  datetime.date(2017, 6, 19) datetime.date(2017, 5, 25)
#  datetime.date(2017, 5, 29) datetime.date(2017, 5, 26)
#  datetime.date(2017, 6, 17) datetime.date(2017, 5, 7)
#  datetime.date(2017, 5, 2) datetime.date(2017, 6, 20)
#  datetime.date(2017, 5, 14) datetime.date(2017, 6, 18)
#  datetime.date(2017, 5, 17) datetime.date(2017, 5, 4)
#  datetime.date(2017, 5, 8) datetime.date(2017, 5, 21)
#  datetime.date(2017, 5, 18) datetime.date(2017, 5, 1)
#  datetime.date(2017, 5, 6) datetime.date(2017, 5, 5)]
# 98

# %% [markdown]
# Hay 98 fechas diferentes

# %%
F.categorico(df_union,"visitor_id")
# Out:
# visitor_id
# 722943003_3441581446     104
# 857376424_12378092455     90
# 272742682_16716805486     81
# 78799102_14329268381      80
# 780189529_68744403580     80
#                         ...
# 88841292_90554922793       1
# 264105320_46576516843      1
# 317566855_11550046963      1
# 757576222_89795938001      1
# 62164232_58679532486       1
# Name: count, Length: 130236, dtype: int64
# ['580560515_7732621733' '39393514_33118319366' '762728880_76361333336' ...
#  '473024645_56027518531' '388766751_9038881013' '947159805_81558194550']
# 130236

# %% [markdown]
# ## Cargamos los datos de la lista de experimentos

# %%
df_experimentos = pd.read_csv('df_final_experiment_clients.txt')

# %% [markdown]
# Observamos los datos:

# %%
df_experimentos.head()
# Out:
#    client_id Variation
# 0    9988021      Test
# 1    8320017      Test
# 2    4033851   Control
# 3    1982004      Test
# 4    9294070   Control

# %% [markdown]
# ### Analizamos los datos

# %%
F.explorar_df(df_experimentos)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 70609 entries, 0 to 70608
# Data columns (total 2 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   client_id  70609 non-null  int64
#  1   Variation  50500 non-null  object
# dtypes: int64(1), object(1)
# memory usage: 1.1+ MB
# None
# Primeras filas
#    client_id Variation
# 0    9988021      Test
# 1    8320017      Test
# 2    4033851   Control
# 3    1982004      Test
# 4    9294070   Control
# Describe()
#              count unique   top   freq            mean             std    min  \
# client_id  70609.0    NaN   NaN    NaN  5004991.876574  2877277.629755  169.0
# Variation    50500      2  Test  26968             NaN             NaN    NaN
#
#                  25%        50%        75%        max
# client_id  2519329.0  5016978.0  7483085.0  9999839.0
# Variation        NaN        NaN        NaN        NaN
# Nulos
# Variation    20109
# dtype: int64
# Duplicados
# 0
# Tamaño
# Filas: 70609 | Columnas: 2

# %% [markdown]
# No tiene datos duplicados pero si nulos. Veamos los nulos:

# %%
nulos_exp=F.ver_nulos(df_experimentos)
# Out:
#        client_id Variation
# 50500    5459747       NaN
# 50501    8031000       NaN
# 50502    1847030       NaN
# 50503    9713157       NaN
# 50504    7775828       NaN
# ...          ...       ...
# 70604    2443347       NaN
# 70605    8788427       NaN
# 70606     266828       NaN
# 70607    1266421       NaN
# 70608    9895983       NaN
#
# [20109 rows x 2 columns]
